# %%
import pandas as pd
import numpy as np

test = pd.read_csv('data/test.csv')
train = pd.read_csv('data/train.csv')
sub = pd.read_csv('data/sample_submission.csv')

# %%
# 랜덤 시드를 고정하기 위한 코드
import os
import random

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
seed_everything(42) # Seed 고정

# %% [markdown]
# #### 버전 확인

# %%
#!pip list
# Out:
# /usr/local/lib/python3.8/dist-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /usr/local/lib/python3.8/dist-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# Package                             Version
# ----------------------------------- ---------------------
# absl-py                             0.10.0
# aiohttp                             3.8.1
# aiosignal                           1.2.0
# aiozmq                              0.9.0
# alembic                             1.4.1
# ansi2html                           1.7.0
# anyio                               3.5.0
# apache-beam                         2.34.0
# appdirs                             1.4.3
# argo-workflows                      3.6.1
# argon2-cffi                         21.3.0
# argon2-cffi-bindings                21.2.0
# asgiref                             3.5.0
# astor                               0.8.1
# astroid                             2.2.5
# astropy                             5.0.1
# asttokens                           2.0.5
# astunparse                          1.6.3
# async-generator                     1.10
# async-timeout                       4.0.2
# atari-py                            0.2.9
# atlas                               0.27.0
# atomicwrites                        1.3.0
# attrs                               20.3.0
# audioread                           2.1.8
# autograd                            1.5
# autograd-gamma                      0.5.0
# autopep8                            1.5
# avro-python3                        1.9.2.1
# azure-core                          1.8.2
# azure-storage-blob                  12.5.0
# Babel                               2.9.1
# backcall                            0.2.0
# bayesian-optimization               1.1.0
# beautifulsoup4                      4.6.0
# beniget                             0.3.0
# biwrap                              0.1.6
# black                               21.12b0
# BlackBoxAuditing                    0.1.54
# bleach                              4.1.0
# bokeh                               1.4.0
# boltons                             21.0.0
# boto                                2.49.0
# boto3                               1.9.209
# botocore                            1.12.209
# branca                              0.4.0
# Brotli                              1.0.9
# bz2file                             0.98
# cachetools                          4.2.4
# Cartopy                             0.18.0
# catboost                            0.24.4
# category-encoders                   2.0.0
# certifi                             2020.6.20
# certipy                             0.1.3
# cffi                                1.15.0
# chardet                             3.0.4
# charset-normalizer                  2.0.12
# chex                                0.1.0
# click                               7.1.2
# click-plugins                       1.1.1
# cligj                               0.7.2
# cloudpickle                         1.5.0
# cmdstanpy                           0.9.5
# colorama                            0.4.4
# colored                             1.4.3
# colour                              0.1.5
# commonmark                          0.9.1
# contextlib2                         0.5.5
# convertdate                         2.3.2
# coverage                            4.5.4
# crcmod                              1.7
# cryptography                        36.0.1
# cupy                                10.1.0
# cvxpy                               1.1.18
# cx-Oracle                           8.0.1
# cycler                              0.11.0
# Cython                              0.29.28
# dacite                              1.6.0
# dash                                2.2.0
# dash-core-components                2.0.0
# dash-html-components                2.0.0
# dash-table                          5.0.0
# dask                                2.9.0
# databricks-cli                      0.12.0
# dataclasses                         0.6
# dbus-python                         1.2.16
# deap                                1.3.1
# debugpy                             1.5.1
# decorator                           5.1.1
# deepdish                            0.3.6
# deepmerge                           0.1.0
# defusedxml                          0.7.1
# deprecation                         2.1.0
# descartes                           1.1.0
# dill                                0.3.1.1
# distributed                         2.11.0
# dm-haiku                            0.0.2
# dm-sonnet                           2.0.0
# dm-tree                             0.1.5
# docker                              4.3.1
# docopt                              0.6.2
# docutils                            0.15.2
# dopamine-rl                         3.1.7
# dtreeviz                            0.8.1
# EasyProcess                         0.3
# ecdsa                               0.17.0
# ecos                                2.0.7.post1
# einops                              0.3.2
# elegy                               0.8.4
# eliot                               1.14.0
# eliot-tree                          21.0.0
# entrypoints                         0.4
# enum34                              1.1.10
# ephem                               3.7.6.0
# escapism                            1.0.1
# evdev                               1.4.0
# executing                           0.8.2
# fairness                            0.1.8
# fairness-indicators                 0.36.0
# fastavro                            0.23.6
# fasteners                           0.15
# fastrlock                           0.8
# featuretools                        0.9.1
# filelock                            3.0.12
# Fiona                               1.8.21
# fire                                0.4.0
# flake8                              5.0.4
# Flask                               1.1.2
# Flask-Compress                      1.10.1
# flatbuffers                         2.0
# flax                                0.3.4
# folium                              0.10.0
# fonttools                           4.29.1
# formulaic                           0.5.2
# frozenlist                          1.3.0
# funcsigs                            1.0.2
# funcy                               1.13
# future                              0.18.2
# gast                                0.4.0
# GDAL                                3.0.4
# gensim                              3.8.0
# geopandas                           0.5.1
# gevent                              20.9.0
# gin-config                          0.3.0
# gitdb                               4.0.9
# GitPython                           3.1.27
# google-api-core                     1.31.5
# google-api-python-client            1.12.10
# google-apitools                     0.5.31
# google-auth                         1.35.0
# google-auth-httplib2                0.1.0
# google-auth-oauthlib                0.4.1
# google-cloud-aiplatform             1.10.0
# google-cloud-bigquery               2.26.0
# google-cloud-bigquery-storage       2.12.0
# google-cloud-bigtable               1.7.0
# google-cloud-core                   1.7.2
# google-cloud-datastore              1.15.3
# google-cloud-dlp                    1.0.0
# google-cloud-language               1.3.0
# google-cloud-pubsub                 1.7.0
# google-cloud-recommendations-ai     0.2.0
# google-cloud-spanner                1.19.1
# google-cloud-storage                1.44.0
# google-cloud-videointelligence      1.16.0
# google-cloud-vision                 1.0.0
# google-crc32c                       1.0.0
# google-images-download              2.8.0
# google-pasta                        0.2.0
# google-resumable-media              2.3.0
# googleapis-common-protos            1.52.0
# gorilla                             0.3.0
# graphlib-backport                   1.0.3
# graphviz                            0.14.2
# greenlet                            1.1.2
# grpc-google-iam-v1                  0.12.3
# grpcio                              1.38.1
# grpcio-gcp                          0.2.2
# gunicorn                            20.0.4
# gym                                 0.17.3
# h5grove                             0.0.14
# h5py                                3.6.0
# hdf5storage                         0.1.15
# hdfs                                2.5.8
# HeapDict                            1.0.1
# holidays                            0.10.2
# horovod                             0.23.0
# httplib2                            0.17.4
# hyperopt                            0.1.2
# idna                                2.10
# idna-ssl                            1.1.0
# imageio                             2.8.0
# imbalanced-learn                    0.5.0
# importlib-metadata                  4.11.1
# importlib-resources                 5.4.0
# interface-meta                      1.3.0
# ipykernel                           6.9.1
# ipyparallel                         6.2.4
# ipython                             7.31.1
# ipython-genutils                    0.2.0
# ipywidgets                          7.6.5
# iso8601                             1.0.2
# isodate                             0.6.0
# isort                               4.3.21
# itsdangerous                        2.1.0
# jax                                 0.3.1
# jaxlib                              0.3.0
# jedi                                0.17.2
# jeepney                             0.4.3
# Jinja2                              2.11.3
# jmespath                            0.10.0
# joblib                              1.2.0
# JPype1                              0.7.2
# json-tricks                         3.14.0
# json5                               0.9.6
# jsonpickle                          1.5.2
# jsonschema                          4.4.0
# jupyter                             1.0.0
# jupyter-bokeh                       1.1.1
# jupyter-client                      6.1.12
# jupyter-console                     6.4.0
# jupyter-contrib-core                0.3.3
# jupyter-contrib-nbextensions        0.5.1
# jupyter-core                        4.9.2
# jupyter-dash                        0.4.1
# jupyter-highlight-selected-word     0.2.0
# jupyter-js-widgets-nbextension      0.0.2.dev0
# jupyter-kite                        2.0.2
# jupyter-latex-envs                  1.4.6
# jupyter-lsp                         1.5.1
# jupyter-nbextensions-configurator   0.4.1
# jupyter-packaging                   0.11.1
# jupyter-server                      1.13.2
# jupyter-server-mathjax              0.2.5
# jupyter-server-proxy                1.5.2
# jupyter-telemetry                   0.1.0
# jupyterhub                          2.1.1
# jupyterhub-jwtauthenticator         0.1
# jupyterhub-kubespawner              0.16.1
# jupyterhubutils                     0.25.0
# jupyterlab                          3.2.9
# jupyterlab-code-formatter           1.4.10
# jupyterlab-git                      0.24.0
# jupyterlab-github                   3.0.1
# jupyterlab-hdf                      1.2.0
# jupyterlab-launcher                 0.13.1
# jupyterlab-lsp                      3.10.0
# jupyterlab-nvdashboard              0.3.1
# jupyterlab-pygments                 0.1.2
# jupyterlab-server                   2.10.3
# jupyterlab-widgets                  1.0.2
# jupyterlabutils                     0.9.2
# jupyterthemes                       0.20.0
# jupytext                            1.13.7
# kaggle                              1.5.12
# keras                               2.7.0
# Keras-Applications                  1.0.8
# Keras-Preprocessing                 1.1.2
# keras-tuner                         1.1.0
# keyring                             21.4.0
# kfac                                0.2.0
# kiwisolver                          1.3.2
# klib                                0.1.1
# konlpy                              0.5.2
# korean-lunar-calendar               0.2.1
# Korpora                             0.1.1
# kss                                 1.3.1
# kt-legacy                           1.0.4
# kubernetes                          12.0.1
# lazy-object-proxy                   1.4.3
# lesscpy                             0.15.0
# libclang                            13.0.0
# libcst                              0.4.1
# librosa                             0.6.3
# lifelines                           0.27.4
# lightgbm                            3.0.0
# lime                                0.1.1.37
# llvmlite                            0.31.0
# LunarCalendar                       0.0.9
# lunardate                           0.2.0
# lxml                                4.8.0
# Mako                                1.1.0
# maproxy                             0.0.12
# Markdown                            3.3
# markdown-it-py                      1.1.0
# MarkupSafe                          1.1.1
# matplotlib                          3.5.1
# matplotlib-inline                   0.1.3
# mccabe                              0.7.0
# mdit-py-plugins                     0.3.0
# mesh-tensorflow                     0.1.19
# meshio                              4.2.2
# mimeparse                           0.1.3
# mistune                             0.8.4
# ml-metadata                         1.5.0
# ml-pipelines-sdk                    1.5.0
# mlflow                              1.12.1
# mlflow-extend                       0.1.6
# mlxtend                             0.17.2
# mmdnn                               0.3.1
# mne                                 0.20.5
# mock                                4.0.3
# monotonic                           1.5
# more-itertools                      7.2.0
# mpi4py                              3.0.3
# mpmath                              1.1.0
# msgpack                             0.6.1
# msgpack-python                      0.5.6
# msrest                              0.6.19
# multidict                           6.0.2
# multiprocess                        0.70.9
# munch                               2.5.0
# mypy-extensions                     0.4.3
# namedlist                           1.7
# nbclassic                           0.3.5
# nbclient                            0.5.11
# nbconvert                           6.4.2
# nbdime                              2.1.1
# nbformat                            5.1.3
# nest-asyncio                        1.5.4
# netifaces                           0.10.9
# networkx                            2.4
# neural-structured-learning          1.3.1
# ngboost                             0.3.13
# nltk                                3.2.5
# nni                                 1.9
# nodejs                              0.1.1
# nose                                1.3.7
# notebook                            6.4.8
# numba                               0.48.0
# numexpr                             2.7.0
# numpy                               1.23.5
# nvidia-dali-cuda110                 1.11.0
# nvidia-dali-tf-plugin-cuda110       1.11.0
# oauth2client                        4.1.3
# oauthenticator                      0.13.0
# oauthlib                            3.2.0
# onnx                                1.8.1
# opencv-python                       4.4.0.44
# opt-einsum                          3.3.0
# optax                               0.0.9
# optional-django                     0.1.0
# orjson                              3.6.7
# osqp                                0.6.2
# packaging                           20.4
# pamela                              1.0.0
# pandas                              1.5.2
# pandasgui                           0.2.7
# pandocfilters                       1.5.0
# parso                               0.7.1
# pathspec                            0.9.0
# patsy                               0.5.1
# pbr                                 5.5.0
# pexpect                             4.8.0
# pickleshare                         0.7.5
# Pillow                              9.0.1
# pip                                 22.0.3
# pkginfo                             1.5.0.1
# platformdirs                        2.5.1
# plotly                              5.6.0
# pluggy                              0.12.0
# ply                                 3.11
# pooch                               1.2.0
# portpicker                          1.3.1
# progressbar                         2.5
# prometheus-client                   0.13.1
# prometheus-flask-exporter           0.18.0
# promise                             2.3
# prompt-toolkit                      3.0.7
# proto-plus                          1.20.3
# protobuf                            3.19.4
# psutil                              5.9.0
# ptyprocess                          0.7.0
# pure-eval                           0.2.2
# py                                  1.8.0
# py-cpuinfo                          7.0.0
# pyaml                               19.12.0
# pyarrow                             1.0.1
# pyasn1                              0.4.8
# pyasn1-modules                      0.2.8
# pybind11                            2.9.1
# pycairo                             1.19.0
# pycodestyle                         2.9.1
# pycparser                           2.21
# pydocstyle                          5.0.2
# pydot                               1.4.1
# pydotplus                           2.0.2
# pydotz                              1.5.1
# pyerfa                              2.0.0.1
# pyflakes                            2.5.0
# pygad                               2.8.0
# pygal                               2.4.0
# pygame                              1.9.6
# pyglet                              1.5.0
# Pygments                            2.11.2
# PyGObject                           3.42.0
# pyLDAvis                            2.1.2
# pylint                              2.3.1
# pyls-black                          0.4.4
# PyMeeus                             0.5.11
# pymongo                             3.11.0
# pynput                              1.7.6
# pynvml                              11.4.1
# pyOpenSSL                           22.0.0
# pyparsing                           2.4.7
# pypng                               0.0.20
# pyproj                              2.5.0
# PyQt5                               5.15.0
# PyQt5-sip                           12.8.1
# PyQtWebEngine                       5.15.2
# pyrsistent                          0.18.1
# pyshp                               2.1.0
# PySocks                             1.7.1
# pystan                              2.19.1.1
# pytest                              5.4.3
# pytest-cov                          2.10.1
# python-apt                          2.0.0+ubuntu0.20.4.7
# python-dateutil                     2.8.2
# python-editor                       1.0.4
# python-jose                         3.3.0
# python-json-logger                  2.0.2
# python-jsonrpc-server               0.4.0
# python-language-server              0.36.2
# python-slugify                      6.1.0
# python-speech-features              0.6
# python-xlib                         0.31
# PythonWebHDFS                       0.2.3
# pythran                             0.9.8
# pytz                                2021.3
# PyVirtualDisplay                    1.3.2
# pyvista                             0.24.3
# pyvo                                1.3
# PyWavelets                          1.1.1
# PyYAML                              5.4.1
# pyzmq                               22.3.0
# qdldl                               0.1.5.post0
# qgrid                               1.3.1
# qtconsole                           5.2.2
# QtPy                                2.0.1
# querystring-parser                  1.2.4
# readme-renderer                     26.0
# rednose                             1.3.0
# regex                               2020.2.20
# requests                            2.25.1
# requests-oauthlib                   1.3.1
# requests-toolbelt                   0.9.1
# requests-unixsocket                 0.2.0
# resampy                             0.2.1
# responses                           0.18.0
# retrying                            1.3.3
# rfc3986                             1.4.0
# rich                                10.16.2
# rope                                0.16.0
# rouge-score                         0.0.4
# rsa                                 4.8
# ruamel.yaml                         0.17.21
# ruamel.yaml.clib                    0.2.6
# s3transfer                          0.2.1
# sacrebleu                           1.3.6
# sacred                              0.8.1
# sacremoses                          0.0.43
# schema                              0.7.1
# scikit-image                        0.17.1
# scikit-learn                        1.2.0
# scikit-nni                          0.2.1
# scikit-optimize                     0.7.4
# scikit-plot                         0.3.7
# scikit-surprise                     1.1.0
# scipy                               1.8.0
# scooby                              0.5.6
# scs                                 3.2.0
# seaborn                             0.11.1
# SecretStorage                       3.1.2
# selenium                            3.141.0
# semver                              2.13.0
# Send2Trash                          1.8.0
# sentencepiece                       0.1.94
# setuptools                          60.9.3
# setuptools-git                      1.2
# Shapely                             1.7.0
# simpervisor                         0.4
# simpleaudio                         1.0.4
# simplejson                          3.17.0
# six                                 1.15.0
# sklearn                             0.0
# smart-open                          1.9.0
# smmap                               5.0.0
# smogn                               0.1.1
# sniffio                             1.2.0
# snowballstemmer                     2.0.0
# sortedcontainers                    2.1.0
# soynlp                              0.0.493
# SQLAlchemy                          1.4.31
# sqlparse                            0.4.0
# stack-data                          0.2.0
# statsmodels                         0.11.1
# stopit                              1.1.2
# sympy                               1.6.2
# t5                                  0.6.4
# tables                              3.6.1
# tabulate                            0.8.7
# tblib                               1.6.0
# tenacity                            8.0.1
# tensorboard                         2.7.0
# tensorboard-data-server             0.6.1
# tensorboard-plugin-wit              1.8.1
# tensorboardX                        2.5
# tensorflow                          2.7.1
# tensorflow-addons                   0.16.1
# tensorflow-constrained-optimization 0.2
# tensorflow-data-validation          1.5.0
# tensorflow-datasets                 4.5.2
# tensorflow-datasets-ko              0.2.3
# tensorflow-estimator                2.7.0
# tensorflow-gan                      2.1.0
# tensorflow-gpu                      2.7.1
# tensorflow-graphics-gpu             1.0.0
# tensorflow-hub                      0.12.0
# tensorflow-io                       0.24.0
# tensorflow-io-gcs-filesystem        0.24.0
# tensorflow-lattice                  2.0.10
# tensorflow-metadata                 1.5.0
# tensorflow-model-analysis           0.36.0
# tensorflow-model-optimization       0.7.1
# tensorflow-plot                     0.3.2
# tensorflow-probability              0.16.0
# tensorflow-ranking                  0.5.0
# tensorflow-serving-api              2.7.0
# tensorflow-text                     2.7.3
# tensorflow-transform                1.5.0
# tensorflowjs                        3.13.0
# tensorwatch                         0.9.1
# termcolor                           1.1.0
# terminado                           0.13.1
# terminaltables                      3.1.0
# termstyle                           0.1.11
# test-generator                      0.1.1
# testpath                            0.5.0
# text-unidecode                      1.3
# tf-slim                             1.1.0
# tfco-nightly                        0.3.dev20220227
# tfds-nightly                        4.2.0.dev202103170106
# tfx                                 1.5.0
# tfx-bsl                             1.5.0
# threadpool                          1.3.2
# threadpoolctl                       2.1.0
# tifffile                            2022.2.9
# tokenizers                          0.9.4
# toml                                0.10.2
# tomli                               1.2.3
# tomlkit                             0.10.0
# toolz                               0.11.2
# torch                               1.10.1
# tornado                             6.1
# TPOT                                0.11.7
# tqdm                                4.55.1
# traitlets                           5.1.1
# transformers                        4.1.1
# trax                                1.3.6
# treeo                               0.0.9
# treex                               0.6.8
# tweepy                              3.8.0
# twine                               3.2.0
# typed-ast                           1.4.2
# typeguard                           2.9.1
# typing                              3.7.4.1
# typing_extensions                   4.4.0
# typing-inspect                      0.7.1
# ujson                               5.1.0
# update-checker                      0.16
# uritemplate                         3.0.1
# urllib3                             1.25.10
# uvloop                              0.14.0
# vecstack                            0.4.0
# versioneer                          0.18
# vtk                                 9.0.1
# wcwidth                             0.2.5
# webencodings                        0.5.1
# websocket-client                    1.2.3
# websockets                          8.1
# Werkzeug                            2.0.3
# wheel                               0.37.1
# widgetsnbextension                  3.5.2
# witwidget                           1.8.1
# witwidget-gpu                       1.6.0
# wrapt                               1.12.1
# xgboost                             1.5.2
# yapf                                0.29.0
# yarl                                1.7.2
# zict                                2.0.0
# zipp                                3.7.0
# zope.event                          4.5.0
# zope.interface                      5.4.0
# WARNING: You are using pip version 22.0.3; however, version 22.3.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# #### 시계열 데이터 분할

# %%
def make_timeseries(data, what):
    data_list = []
    
    if what == 'train':
        col1 = data.iloc[:,6:95] # 새순 피처
        col2 = data.iloc[:,95:] # 엽록소 피처
    elif what == 'test':
        col1 = data.iloc[:,5:94] # 새순 피처
        col2 = data.iloc[:,94:] # 엽록소 피처
    
    tcol1 = col1.T
    tcol2 = col2.T
        
    tcol1.columns = data['ID']
    tcol2.columns = data['ID']+str('_1') # 새순과 엽록소 구분을 위해 '_1' 추가

    tcol1= tcol1.reset_index()
    date_lst = tcol1['index'].apply(lambda x: x.split('새')[0]) # 9월부터 11월까지 날짜 데이터를 추출하기 위해 data_lst를 만듦
    tcol1 = tcol1.drop('index', axis=1) 
    tcol2= tcol2.reset_index().drop('index', axis=1) 

    for id in data['ID']:
        # ID에 따라 각 날짜별 새순과 엽록소 값을 합친다음,
        md = pd.concat([tcol1[f'{id}'], tcol2[f'{id}_1']], axis=1)
        md = md.rename(columns = {f'{id}' : '새순', f'{id}_1' : '엽록소'})
        # 이후 나머지 피처값들을 받는다
        md['ID'] = id
        md['수고'] = float(data.loc[data['ID'] == id, '수고(m)'])
        md['수관폭_min'] = float(data.loc[data['ID'] == id, '수관폭1(min)'])
        md['수관폭_max'] = float(data.loc[data['ID'] == id, '수관폭2(max)'])
        md['수관폭_mean'] = float(data.loc[data['ID'] == id, '수관폭평균'])
        md['date'] = date_lst  
        data_list.append(md)

    td = pd.concat(data_list)

    return td

# %%
train1 = make_timeseries(train, 'train')
test1 = make_timeseries(test, 'test')

# %%
# 날짜 데이터에서 월 추출
train1['month'] = pd.to_datetime(train1.date).dt.month
train1 = train1.drop('date',axis=1)

test1['month'] = pd.to_datetime(test1.date).dt.month
test1 = test1.drop('date',axis=1)

# %%
#새순

# 새순_diff = train1.groupby('ID').새순.diff().to_frame()
# train1['새순_diff'] =np.where(새순_diff.새순<-0.2,1,0)

# 새순_diff_te = test1.groupby('ID').새순.diff().to_frame()
# test1['새순_diff'] =np.where(새순_diff_te.새순<-0.2,1,0)

# 새순_diff = train1.groupby('ID').새순_diff.sum().reset_index()
# 새순_diff_te = test1.groupby('ID').새순_diff.sum().reset_index()

# %% [markdown]
# #### Describe Data

# %%
새순_describe = train1.groupby(['ID','month'])['새순'].describe().unstack().reset_index().drop('count',axis=1)
새순_describe.columns = ['ID','새순_mean_9','새순_mean_10','새순_mean_11',
            '새순_std_9','새순_std_10','새순_std_11','새순_min_9','새순_min_10',
            '새순_min_11','새순_25_9','새순_25_10', '새순_25_11', '새순_50_9',
            '새순_50_10', '새순_50_11','새순_75_9', '새순_75_10','새순_75_11',
            '새순_max_9', '새순_max_10', '새순_max_11']

새순_describe_te = test1.groupby(['ID','month'])['새순'].describe().unstack().reset_index().drop('count',axis=1)
새순_describe_te.columns = ['ID','새순_mean_9','새순_mean_10','새순_mean_11',
            '새순_std_9','새순_std_10','새순_std_11','새순_min_9','새순_min_10',
            '새순_min_11','새순_25_9','새순_25_10', '새순_25_11', '새순_50_9',
            '새순_50_10', '새순_50_11','새순_75_9', '새순_75_10','새순_75_11',
            '새순_max_9', '새순_max_10', '새순_max_11']
# Out:
# /tmp/ipykernel_252/1848495427.py:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   새순_describe = train1.groupby(['ID','month'])['새순'].describe().unstack().reset_index().drop('count',axis=1)
# /tmp/ipykernel_252/1848495427.py:8: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   새순_describe_te = test1.groupby(['ID','month'])['새순'].describe().unstack().reset_index().drop('count',axis=1)

# %%
data = pd.merge(train.iloc[:,:6], 새순_describe, how='left', on='ID')
data = pd.merge(data, 엽록소_describe, how='left', on='ID')

data_te = pd.merge(test.iloc[:,:5], 새순_describe_te, how='left', on='ID')
data_te = pd.merge(data_te, 엽록소_describe_te, how='left', on='ID')

# %% [markdown]
# #### Heuristics Data

# %%
data['수관폭_diff'] = data['수관폭2(max)']-data['수관폭1(min)']
data['수관폭_rate'] = data['수관폭2(max)']/data['수관폭1(min)']
data['수관하중'] = data['수관폭평균']/data['수고(m)']

data_te['수관폭_diff'] = data_te['수관폭2(max)']-data_te['수관폭1(min)']
data_te['수관폭_rate'] = data_te['수관폭2(max)']/data_te['수관폭1(min)']
data_te['수관하중'] = data_te['수관폭평균']/data_te['수고(m)']

# %%
data['새순_mean_9_2'] = data['새순_mean_9']**2
# data['새순_25_9_2'] = data['새순_25_9']**2
# data['새순_50_9_2'] = data['새순_50_9']**2
data['새순_75_9_2'] = data['새순_75_9']**2
data['새순_max_9_2'] = data['새순_max_9']**2

data_te['새순_mean_9_2'] = data_te['새순_mean_9']**2
# data_te['새순_25_9_2'] = data_te['새순_25_9']**2
# data_te['새순_50_9_2'] = data_te['새순_50_9']**2
data_te['새순_75_9_2'] = data_te['새순_75_9']**2
data_te['새순_max_9_2'] = data_te['새순_max_9']**2

# %%
data = pd.concat([data, train.iloc[:,6:]],axis=1)
data_te = pd.concat([data_te, test.iloc[:,5:]],axis=1)

# %% [markdown]
# #### Data split

# %%
x_train = data.drop(['ID','착과량(int)'],axis=1)
y_train = data['착과량(int)']
x_test = data_te.drop(['ID'],axis=1)

# %% [markdown]
# #### Data Scaler

# %%
col_lst = x_train.columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

x_train = scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)

x_train=pd.DataFrame(x_train,columns=col_lst)
x_test=pd.DataFrame(x_test,columns=col_lst)

# %% [markdown]
# ### Feature Selection

# %%
from sklearn.linear_model import Ridge

from sklearn.feature_selection import SelectPercentile
from sklearn.model_selection import cross_val_score

from tqdm import tqdm, tqdm_notebook
import matplotlib.pyplot as plt

# %%
# 사용할 모델 설정 (속도가 빠른 모델 사용 권장)
model = Ridge(random_state=0)

# 각 특성과 타깃(class) 사이에 유의한 통계적 관계가 있는지 계산하여 특성을 선택하는 방법 
cv_scores = []
for p in tqdm(range(5,100,1)):
    X_new = SelectPercentile(percentile=p).fit_transform(x_train, y_train)    #SelectPercentile: 지정된 비율만큼 특성을 선택한다.
    cv_score = cross_val_score(model, X_new, y_train, scoring='neg_mean_absolute_error', cv=5).mean()
    cv_scores.append((p,cv_score))

# Print the best percentile
best_score = cv_scores[np.argmax([score for _, score in cv_scores])]
print(best_score)

# Plot the performance change with p
plt.plot([k for k, _ in cv_scores], [score for _, score in cv_scores])
plt.xlabel('Percent of features')
plt.grid()
# Out:
# 100% 95/95 [00:08<00:00, 11.47it/s]
# (6, -34.37175569016353)

# %%
# 과적합을 피하기 위해 최적의 p값 주변의 값을 선택하는게 더 나은 결과를 얻을 수 있다. 
fs = SelectPercentile(percentile=best_score[0]).fit(x_train, y_train)
x_train_select = fs.transform(x_train)
x_test_select = fs.transform(x_test)

# %%
print(x_train_select.shape)
print(x_train.columns[fs.get_support()].tolist())
# Out:
# (2207, 14)
# ['새순_mean_9', '새순_50_9', '새순_75_9', '새순_max_9', '새순_mean_9_2', '새순_75_9_2', '새순_max_9_2', '2022-09-01 새순', '2022-09-02 새순', '2022-09-03 새순', '2022-09-04 새순', '2022-09-05 새순', '2022-09-06 새순', '2022-09-07 새순']

# %%
x_train_select = pd.DataFrame(x_train_select, columns =x_train.columns[fs.get_support()].tolist())
x_test_select = pd.DataFrame(x_test_select, columns =x_test.columns[fs.get_support()].tolist())

# %% [markdown]
# ### Modeling

# %%
# !pip install --upgrade ngboost

# %%
from sklearn.model_selection import TimeSeriesSplit, KFold
from ngboost import NGBRegressor
from ngboost.distns import Exponential, Normal
from ngboost.scores import MLE
from ngboost.learners import default_tree_learner

def NMAE(true, pred):
    mae = np.mean(np.abs(true-pred))
    score = mae / np.mean(np.abs(true))
    return score

# %%
##### 0.07362
ngb = NGBRegressor(n_estimators=20000,  natural_gradient=True, 
                   learning_rate = 0.01,Base=default_tree_learner, 
                   Dist=Normal, Score=MLE, verbose_eval =50, random_state=0)

kf = KFold(n_splits = 5, shuffle=True, random_state=0)

ngb_pred_1 = np.zeros((x_test_select.shape[0]))
nmae_list = []
for tr_idx, val_idx in kf.split(x_train_select):
    tr_x, val_x = x_train_select.iloc[tr_idx], x_train_select.iloc[val_idx]
    tr_y, val_y = y_train.iloc[tr_idx], y_train.iloc[val_idx]
    ngb.fit(tr_x, tr_y, val_x, val_y, early_stopping_rounds = 500)
    pred = ngb.predict(val_x)
    nmae = NMAE(val_y, pred)
    nmae_list.append(nmae)
    print(f'FOLD NMAE = {nmae}')
    sub_pred = ngb.predict(x_test_select) / 5
    ngb_pred_1 += sub_pred
print(f'\n{ngb.__class__.__name__} NMAE = {np.mean(nmae_list)}')
# Out:
# [iter 0] loss=6.8136 val_loss=6.7723 scale=1.0000 norm=189.9940
# [iter 50] loss=6.1813 val_loss=6.1602 scale=2.0000 norm=154.2432
# [iter 100] loss=5.7339 val_loss=5.7186 scale=2.0000 norm=75.9693
# [iter 150] loss=5.3712 val_loss=5.3662 scale=2.0000 norm=60.1041
# [iter 200] loss=5.1256 val_loss=5.1387 scale=2.0000 norm=57.4639
# [iter 250] loss=4.9924 val_loss=5.0299 scale=2.0000 norm=56.7450
# [iter 300] loss=4.9315 val_loss=4.9963 scale=2.0000 norm=56.2266
# [iter 350] loss=4.9013 val_loss=4.9871 scale=2.0000 norm=55.8266
# [iter 400] loss=4.8835 val_loss=4.9862 scale=2.0000 norm=55.5137
# [iter 450] loss=4.8716 val_loss=4.9873 scale=2.0000 norm=55.2419
# [iter 500] loss=4.8620 val_loss=4.9912 scale=2.0000 norm=55.0200
# [iter 550] loss=4.8543 val_loss=4.9971 scale=2.0000 norm=54.8288
# [iter 600] loss=4.8465 val_loss=5.0032 scale=2.0000 norm=54.6316
# [iter 650] loss=4.8396 val_loss=5.0088 scale=2.0000 norm=54.4294
# [iter 700] loss=4.8324 val_loss=5.0138 scale=2.0000 norm=54.2366
# [iter 750] loss=4.8259 val_loss=5.0189 scale=2.0000 norm=54.0293
# [iter 800] loss=4.8190 val_loss=5.0246 scale=1.0000 norm=26.9153
# [iter 850] loss=4.8124 val_loss=5.0301 scale=2.0000 norm=53.6471
# == Early stopping achieved.
# == Best iteration / VAL387 (val_loss=4.9851)
# FOLD NMAE = 0.0745632509418274
# [iter 0] loss=4.8687 val_loss=4.8162 scale=1.0000 norm=27.5924
# [iter 50] loss=4.8478 val_loss=4.8190 scale=1.0000 norm=27.4502
# [iter 100] loss=4.8370 val_loss=4.8239 scale=1.0000 norm=27.3157
# [iter 150] loss=4.8312 val_loss=4.8285 scale=1.0000 norm=27.2111
# [iter 200] loss=4.8259 val_loss=4.8317 scale=1.0000 norm=27.1197
# [iter 250] loss=4.8192 val_loss=4.8360 scale=2.0000 norm=54.0438
# [iter 300] loss=4.8125 val_loss=4.8390 scale=1.0000 norm=26.9102
# [iter 350] loss=4.8063 val_loss=4.8431 scale=1.0000 norm=26.8145
# [iter 400] loss=4.8007 val_loss=4.8485 scale=2.0000 norm=53.4550
# [iter 450] loss=4.7948 val_loss=4.8548 scale=2.0000 norm=53.2753
# == Early stopping achieved.
# == Best iteration / VAL0 (val_loss=4.8162)
# FOLD NMAE = 0.07057572686157194
# [iter 0] loss=4.8322 val_loss=4.7665 scale=2.0000 norm=54.7376
# [iter 50] loss=4.8105 val_loss=4.7658 scale=2.0000 norm=53.9631
# [iter 100] loss=4.8004 val_loss=4.7693 scale=2.0000 norm=53.5513
# [iter 150] loss=4.7929 val_loss=4.7735 scale=2.0000 norm=53.2480
# [iter 200] loss=4.7848 val_loss=4.7788 scale=2.0000 norm=52.9802
# [iter 250] loss=4.7779 val_loss=4.7843 scale=2.0000 norm=52.7237
# [iter 300] loss=4.7727 val_loss=4.7898 scale=1.0000 norm=26.2519
# [iter 350] loss=4.7672 val_loss=4.7956 scale=2.0000 norm=52.2649
# [iter 400] loss=4.7627 val_loss=4.8021 scale=2.0000 norm=52.0792
# [iter 450] loss=4.7578 val_loss=4.8090 scale=1.0000 norm=25.9470
# [iter 500] loss=4.7526 val_loss=4.8164 scale=2.0000 norm=51.7226
# == Early stopping achieved.
# == Best iteration / VAL20 (val_loss=4.7642)
# FOLD NMAE = 0.06460573640420487
# [iter 0] loss=4.7813 val_loss=4.7108 scale=1.0000 norm=26.3727
# [iter 50] loss=4.7686 val_loss=4.7182 scale=2.0000 norm=52.3199
# [iter 100] loss=4.7614 val_loss=4.7267 scale=1.0000 norm=26.0059
# [iter 150] loss=4.7559 val_loss=4.7348 scale=2.0000 norm=51.7640
# [iter 200] loss=4.7524 val_loss=4.7399 scale=1.0000 norm=25.8100
# [iter 250] loss=4.7493 val_loss=4.7451 scale=2.0000 norm=51.4912
# [iter 300] loss=4.7458 val_loss=4.7517 scale=1.0000 norm=25.6704
# [iter 350] loss=4.7415 val_loss=4.7628 scale=0.5000 norm=12.7960
# [iter 400] loss=4.7369 val_loss=4.7714 scale=0.5000 norm=12.7545
# [iter 450] loss=4.7331 val_loss=4.7821 scale=2.0000 norm=50.8724
# == Early stopping achieved.
# == Best iteration / VAL0 (val_loss=4.7108)
# FOLD NMAE = 0.06182246267810101
# [iter 0] loss=4.7561 val_loss=4.6854 scale=1.0000 norm=25.5833
# [iter 50] loss=4.7453 val_loss=4.6913 scale=1.0000 norm=25.4687
# [iter 100] loss=4.7397 val_loss=4.6952 scale=1.0000 norm=25.3687
# [iter 150] loss=4.7346 val_loss=4.6991 scale=1.0000 norm=25.2702
# [iter 200] loss=4.7302 val_loss=4.7054 scale=1.0000 norm=25.1771
# [iter 250] loss=4.7262 val_loss=4.7141 scale=1.0000 norm=25.0890
# [iter 300] loss=4.7205 val_loss=4.7217 scale=1.0000 norm=24.9908
# [iter 350] loss=4.7154 val_loss=4.7283 scale=2.0000 norm=49.7906
# [iter 400] loss=4.7117 val_loss=4.7337 scale=1.0000 norm=24.8284
# [iter 450] loss=4.7071 val_loss=4.7422 scale=2.0000 norm=49.4984
# == Early stopping achieved.
# == Best iteration / VAL0 (val_loss=4.6854)
# FOLD NMAE = 0.06166377496165415
#
# NGBRegressor NMAE = 0.06664619036947186

# %% [markdown]
# ### Make_submission

# %%
sub['착과량(int)'] = ngb_pred_1
sub
# Out:
#              ID    착과량(int)
# 0     TEST_0000  247.580573
# 1     TEST_0001  758.260893
# 2     TEST_0002  144.427764
# 3     TEST_0003  446.459322
# 4     TEST_0004  686.965029
# ...         ...         ...
# 2203  TEST_2203  753.616102
# 2204  TEST_2204  317.476500
# 2205  TEST_2205  368.908945
# 2206  TEST_2206  251.372176
# 2207  TEST_2207  104.425080
#
# [2208 rows x 2 columns]

# %%
sub.set_index('ID').to_csv('sub/1213_v9.csv')
